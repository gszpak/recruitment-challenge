# %%
# %matplotlib inline

import numpy as np
from matplotlib import pyplot as plot

plot.rcParams["figure.figsize"] = (12, 9)

def plot_distr(distr):
    most_common = distr.most_common(100)
    tags_distr_labels, tags_distr_values = zip(*most_common)
    X = np.arange(len(tags_distr_labels))
    plot.bar(X, tags_distr_values)
    plot.axes().set_xticks(X)
    plot.axes().set_xticklabels(tags_distr_labels, rotation=90)
    ymax = max(tags_distr_values) + 1
    plot.ylim(0, ymax)
    plot.show()

def get_html_from_str(line):
    parsed_line = ujson.loads(line)
    return parsed_line.get('html')

# %%
from collections import Counter

import ujson


KEYS = {'html', 'description', 'industry'}


def get_tags_distr(input_file_path):
    label_distr = Counter()
    instances_without_html = 0
    instances_without_descr = 0
    with open(input_file_path, 'r') as input_file:
        progress = 0
        for line in input_file:
            line_as_json = ujson.loads(line)
            assert set(line_as_json.keys()) <= KEYS
            if 'html' not in line_as_json:
                instances_without_html += 1
            if 'description' not in line_as_json:
                instances_without_descr += 1
            label_distr[line_as_json['industry']] += 1
            progress += 1
            if progress % 1000 == 0:
                print 'Progress: {}'.format(progress)
    print instances_without_html
    print instances_without_descr
    print label_distr
    print len(label_distr)
    plot_distr(label_distr)

    
get_tags_distr('../../data/companies.jsons')
# Out:
# Progress: 1000
# Progress: 2000
# Progress: 3000
# Progress: 4000
# Progress: 5000
# Progress: 6000
# Progress: 7000
# Progress: 8000
# Progress: 9000
# Progress: 10000
# Progress: 11000
# Progress: 12000
# Progress: 13000
# Progress: 14000
# Progress: 15000
# Progress: 16000
# Progress: 17000
# Progress: 18000
# Progress: 19000
# Progress: 20000
# Progress: 21000
# Progress: 22000
# Progress: 23000
# Progress: 24000
# Progress: 25000
# Progress: 26000
# Progress: 27000
# Progress: 28000
# Progress: 29000
# Progress: 30000
# Progress: 31000
# Progress: 32000
# Progress: 33000
# Progress: 34000
# Progress: 35000
# Progress: 36000
# 0
# 0
# Counter({u'Information Technology and Services': 2911, u'Marketing and Advertising': 2415, u'Internet': 1457, u'Construction': 1373, u'Management Consulting': 1340, u'Real Estate': 1180, u'Financial Services': 1055, u'Computer Software': 945, u'Health, Wellness and Fitness': 899, u'Nonprofit Organization Management': 872, u'Education Management': 834, u'Design': 829, u'Hospital & Health Care': 740, u'Retail': 732, u'Automotive': 655, u'Staffing and Recruiting': 635, u'Professional Training & Coaching': 591, u'Law Practice': 580, u'Accounting': 576, u'Food & Beverages': 552, u'Entertainment': 551, u'Human Resources': 546, u'Architecture & Planning': 546, u'Hospitality': 544, u'Telecommunications': 533, u'Events Services': 530, u'Insurance': 513, u'Mechanical or Industrial Engineering': 497, u'Leisure, Travel & Tourism': 494, u'Oil & Energy': 479, u'Electrical/Electronic Manufacturing': 476, u'Media Production': 460, u'Environmental Services': 408, u'Apparel & Fashion': 405, u'Sports': 389, u'Higher Education': 372, u'Legal Services': 369, u'Renewables & Environment': 366, u'Graphic Design': 364, u'Publishing': 357, u'Machinery': 347, u'Consumer Services': 336, u'Consumer Goods': 328, u'Photography': 327, u'Music': 316, u'Transportation/Trucking/Railroad': 309, u'Building Materials': 302, u'Public Relations and Communications': 285, u'Research': 274, u'Printing': 269, u'Medical Practice': 264, u'Wholesale': 264, u'Facilities Services': 256, u'Government Administration': 252, u'Medical Devices': 250, u'Civil Engineering': 244, u'Logistics and Supply Chain': 240, u'Pharmaceuticals': 225, u'Security and Investigations': 223, u'Broadcast Media': 220, u'Civic & Social Organization': 217, u'Online Media': 214, u'Furniture': 211, u'E-Learning': 205, u'Biotechnology': 199})
# 65

# %%
import re

import langdetect
from langdetect.lang_detect_exception import LangDetectException


def has_description(json):
    try:
        langdetect.detect(json['description'])
        return True
    except LangDetectException:
        return False


def has_html(json):
    regexp = re.compile(r'[E|e]rror [4|5]0[0-9]')

# %%
from collections import Counter

from bs4 import BeautifulSoup


def _update_tags_distr(html, tags_distr):
    parsed_html = BeautifulSoup(html, 'html.parser')
    for descendant in parsed_html.descendants:
        if descendant.name is not None:
            tags_distr[descendant.name] += 1


def get_tags_distr(input_file_path):
    tags_distr = Counter()
    with open(input_file_path) as f:
        progress = 0
        for line in f:
            html = get_html_from_str(line)
            if html is None:
                continue
            _update_tags_distr(html, tags_distr)
            if progress % 1000 == 0:
                print 'Progress: {}'.format(progress)
            progress += 1
    plot_distr(tags_distr)

    
get_tags_distr('../../data/companies.jsons')
# Out:
# Progress: 0
# Progress: 1000
# Progress: 2000
# Progress: 3000
# Progress: 4000
# Progress: 5000
# Progress: 6000
# Progress: 7000
# Progress: 8000
# Progress: 9000
# Progress: 10000
# Progress: 11000
# Progress: 12000
# Progress: 13000
# Progress: 14000
# Progress: 15000
# Progress: 16000
# Progress: 17000
# Progress: 18000
# Progress: 19000
# Progress: 20000
# Progress: 21000
# Progress: 22000
# Progress: 23000
# Progress: 24000
# Progress: 25000
# Progress: 26000
# Progress: 27000
# Progress: 28000
# Progress: 29000
# Progress: 30000
# Progress: 31000
# Progress: 32000
# Progress: 33000
# Progress: 34000
# Progress: 35000
# Progress: 36000

# %%
from collections import Counter
import ujson


def _get_lang_from_code(lang_code):
    return lang_code[:2]


def get_lang_distr(input_file_path):
    html_lang_distr = Counter()
    description_lang_distr = Counter()
    with open(input_file_path) as f:
        progress = 0
        for line in f:
            json = ujson.loads(line)
            html_lang = _get_lang_from_code(json['html_language'])
            descr_lang = _get_lang_from_code(json['description_language'])
            html_lang_distr[html_lang] += 1
            description_lang_distr[descr_lang] += 1
            if progress % 1000 == 0:
                print 'Progress: {}'.format(progress)
            progress += 1
    print html_lang_distr
    plot_distr(html_lang_distr)
    print description_lang_distr
    plot_distr(description_lang_distr)
    
get_lang_distr('../../data/companies_cleaned.jsons')
# Out:
# Progress: 0
# Progress: 1000
# Progress: 2000
# Progress: 3000
# Progress: 4000
# Progress: 5000
# Progress: 6000
# Progress: 7000
# Progress: 8000
# Progress: 9000
# Progress: 10000
# Progress: 11000
# Progress: 12000
# Progress: 13000
# Progress: 14000
# Progress: 15000
# Progress: 16000
# Progress: 17000
# Progress: 18000
# Progress: 19000
# Progress: 20000
# Progress: 21000
# Progress: 22000
# Progress: 23000
# Progress: 24000
# Progress: 25000
# Progress: 26000
# Progress: 27000
# Progress: 28000
# Progress: 29000
# Progress: 30000
# Progress: 31000
# Progress: 32000
# Progress: 33000
# Progress: 34000
# Progress: 35000
# Progress: 36000
# Counter({u'en': 28031, u'nl': 1623, u'es': 1587, u'fr': 991, u'pt': 921, u'de': 800, u'it': 651, u'da': 284, u'sv': 262, u'tr': 207, u'ru': 184, u'pl': 154, u'ro': 122, u'cs': 90, u'fi': 89, u'ja': 89, u'zh': 77, u'no': 77, u'tl': 52, u'vi': 51, u'he': 45, u'hr': 43, u'nb': 42, u'hu': 37, u'ca': 34, u'af': 33, u'el': 32, u'et': 31, u'id': 31, u'sk': 31, u'bg': 30, u'lt': 25, u'ko': 24, u'sl': 24, u'ar': 21, u'lv': 20, u'fa': 14, u'sw': 14, u'so': 12, u'uk': 12, u'sr': 8, u'la': 7, u'is': 5, u'th': 5, u'ab': 5, u'sq': 4, u'se': 4, u'bn': 3, u'bs': 3, u'mk': 2, u'ht': 1, u'br': 1, u'si': 1, u'mr': 1})
# Counter({u'en': 29484, u'es': 1915, u'nl': 1520, u'fr': 958, u'pt': 932, u'it': 543, u'de': 365, u'tr': 181, u'da': 176, u'sv': 163, u'ru': 124, u'pl': 82, u'ro': 74, u'no': 73, u'cs': 60, u'fi': 30, u'id': 25, u'zh': 21, u'hr': 21, u'el': 20, u'hu': 18, u'so': 17, u'af': 16, u'he': 16, u'tl': 13, u'ar': 12, u'vi': 11, u'ja': 10, u'sk': 10, u'fa': 9, u'sl': 9, u'lt': 8, u'bg': 7, u'et': 6, u'lv': 5, u'sw': 5, u'uk': 3, u'th': 2, u'sq': 2, u'ko': 1})

# %%
from collections import Counter
import ujson

def get_rare_words(input_file_path):
    words_counts = Counter()
    with open(input_file_path) as f:
        progress = 0
        for line in f:
            json = ujson.loads(line)
            words = set(json['html'] + json['description'])
            for word in words:
                words_counts[word] += 1
            if progress % 1000 == 0:
                print 'Progress: {}'.format(progress)
            progress += 1
    print {word: count for word, count in words_counts.iteritems() if 10 <= count <= 15}
    
    print words_counts.most_common(100)
    
get_rare_words('../../data/companies_transformed.jsons')
# Out:
# Progress: 0
# Progress: 1000
# Progress: 2000
# Progress: 3000
# Progress: 4000
# Progress: 5000
# Progress: 6000
# Progress: 7000
# Progress: 8000
# Progress: 9000
# Progress: 10000
# Progress: 11000
# Progress: 12000
# Progress: 13000
# Progress: 14000
# Progress: 15000
# Progress: 16000
# Progress: 17000
# Progress: 18000
# Progress: 19000
# Progress: 20000
# Progress: 21000
# Progress: 22000
# Progress: 23000
# Progress: 24000
# Progress: 25000
# Progress: 26000
# Progress: 27000
# Progress: 28000
# Progress: 29000
# Progress: 30000
# Progress: 31000
# Progress: 32000
# Progress: 33000
# Progress: 34000
# Progress: 35000
# Progress: 36000
# {u'Ottomans': 11, u'writings': 15, u'Rory': 12, u'Avocado': 11, u'foul': 10, u'pony': 13, u'advices': 15, u'EFFICIENCY': 15, u'prefix': 11, u'spiders': 11, u'DEMAND': 10, u'Thriving': 11, u'logastica': 10, u'mucho': 13, u'canes': 13, u'Petite': 10, u'Adjusting': 15, u'SPS': 10, u'unanswered': 13, u'Nossos': 12, u'SPC': 12, u'Caen': 10, u'SPF': 14, u'sinking': 11, u'swivel': 12, u'shielding': 13, u'Refreshing': 15, u'NATURE': 12, u'Valle': 13, u'interpreters': 10, u'oceans': 14, u'dels': 13, u'967': 10, u'Hier': 12, u'leisurely': 13, u'screaming': 11, u'961': 15, u'disturb': 14, u'Signatures': 12, u'ASSETS': 11, u'probiotic': 12, u'yachting': 13, u'piling': 15, u'south-west': 10, u'Qualitat': 10, u'Rotor': 10, u'gaskets': 12, u'tolerate': 12, u'RFQ': 12, u'276': 11, u'consenting': 15, u'Honorable': 12, u'Zesty': 12, u'flat-rate': 13, u'INSTALLATIONS': 12, u'Fighters': 11, u'Kilimanjaro': 11, u'Cookware': 15, u'voorbehouden': 10, u'shocks': 10, u'self-study': 13, u'Gadsden': 10, u'herb': 12, u'denominations': 11, u'jasmine': 11, u'herd': 13, u'GRC': 11, u'dorm': 15, u'detail-oriented': 10, u'conversational': 14, u'greenery': 14, u'Validated': 12, u'Dominique': 11, u'NOK': 15, u'Catastrophic': 12, u'climbed': 11, u'Jewels': 10, u'Multimodal': 10, u'karin': 15, u'Need-Based': 14, u'vigo': 12, u'leitbild': 11, u'NOS': 15, u'9h': 10, u'koja': 12, u'magically': 10, u'POWERED': 14, u'Configurable': 11, u'Slideshows': 10, u'stern': 10, u'Basil': 11, u'055': 14, u'PROMOTION': 15, u'cocaine': 12, u'Messina': 10, u'053': 12, u'roundtables': 12, u'METHODS': 10, u'insecurity': 12, u'DROP': 13, u'occupying': 10, u'Toby': 14, u'IFAs': 10, u'dns': 14, u'averaging': 13, u'mAh': 10, u'pinpoints': 10, u'funciona': 11, u'Toronto-based': 14, u'Twickenham': 10, u'UNITS': 10, u'excl': 14, u'moto': 14, u'Cliente': 10, u'multi-day': 13, u'EDC': 10, u'EDF': 11, u'EVALUATION': 14, u'Geeks': 11, u'Guiana': 13, u'Prepress': 11, u'Gastronomy': 10, u'Avada': 13, u'Lund': 11, u'rework': 14, u'vanities': 11, u'owes': 12, u'wand': 10, u'hyatt': 11, u'Revive': 15, u'Zoetermeer': 10, u'dragons': 14, u'ABAP': 13, u'DPC': 12, u'cookers': 12, u'DPM': 11, u'pinto': 10, u'cookery': 15, u'ASSURANCE': 12, u'LD': 11, u'Blowing': 10, u'Editorials': 14, u'dvr': 10, u'complaining': 15, u'Montrose': 12, u'DDoS': 12, u'Surfaces': 15, u'LI': 11, u'Polycarbonate': 11, u'mediante': 14, u'LR': 12, u'SURGERY': 10, u'preferable': 14, u'dignified': 15, u'hoy': 12, u'shoreline': 11, u'Bates': 15, u'Alcatel': 15, u'Voce': 11, u'minimums': 12, u'Roughly': 12, u'dinosaurs': 10, u'internic': 15, u'L1': 12, u'LIFETIME': 11, u'HAND': 14, u'CFL': 11, u'CFC': 14, u'Walkers': 11, u'CFA': 14, u'cigarettes': 13, u'queretaro': 11, u'CFR': 13, u'CFS': 10, u'PNG': 11, u'sprawling': 13, u'Inspect': 15, u'Capistrano': 12, u'872': 10, u'shopfitting': 10, u'peut': 13, u'CHALLENGES': 12, u'xi': 14, u'Constructionline': 10, u'Charlottesville': 10, u'jordi': 11, u'Smolensk': 10, u'Circa': 10, u'Ludwig': 10, u'2006-2010': 10, u'Kendal': 10, u'fir': 11, u'ready-to-use': 14, u'Chiropractors': 15, u'auditory': 13, u'Othman': 12, u'DINNER': 11, u'matured': 13, u'Legendary': 15, u'nutraceuticals': 13, u'Implements': 11, u'xa': 14, u'ASSA1': 10, u'on-the-ground': 11, u'commemorate': 13, u'aThemes': 11, u'man-made': 13, u'undeveloped': 12, u'DECISION': 11, u'ideeen': 10, u'Respected': 10, u'water-based': 15, u'timeout': 13, u'APM': 11, u'NPOs': 11, u'Farsi': 12, u'preceded': 13, u'woes': 15, u'ANNOUNCES': 12, u'platelets': 12, u'TELEPHONE': 13, u'393': 13, u'392': 15, u'391': 10, u'fortnight': 12, u'394': 11, u'Jamestown': 14, u'whip': 10, u'borne': 11, u'E-business': 10, u'rv': 15, u'rp': 12, u'waive': 15, u'triptych': 12, u'mason': 15, u'dsl': 14, u'Curiosity': 15, u'Garmin': 12, u'Beratung': 14, u'ENJOY': 11, u'EPDM': 12, u'atA': 14, u'Servizi': 13, u'Ego': 13, u'grapes': 13, u'Slings': 15, u'94305': 10, u'PAYE': 12, u'Raphael': 13, u'competes': 14, u'shipper': 11, u'Cordova': 14, u'ata': 10, u'informazioni': ...
# [(u'and', 35548), (u'of', 33788), (u'the', 33681), (u'to', 33346), (u'in', 32915), (u'is', 31318), (u'for', 29578), (u'with', 27203), (u'on', 23711), (u'our', 23508), (u'are', 23210), (u'that', 21163), (u'we', 20290), (u'by', 20067), (u'your', 19966), (u'you', 19433), (u'We', 19425), (u'an', 18314), (u'The', 17841), (u'from', 17333), (u'as', 16984), (u'or', 16875), (u'more', 16846), (u'all', 16742), (u'at', 16620), (u'have', 16603), (u'us', 16099), (u'Our', 15931), (u'Contact', 15628), (u'company', 15016), (u'services', 14984), (u'can', 14762), (u'has', 14084), (u'Home', 13765), (u'business', 13516), (u'be', 13420), (u'their', 12983), (u'it', 12810), (u'About', 12398), (u'service', 11818), (u'this', 11754), (u'will', 11527), (u'about', 11143), (u'new', 11140), (u'experience', 11043), (u'work', 11037), (u'Us', 10868), (u'provide', 9949), (u'help', 9720), (u'not', 9651), (u'years', 9649), (u'2016', 9498), (u'quality', 9438), (u'out', 9376), (u'also', 9337), (u'one', 9325), (u'do', 9296), (u'through', 9293), (u'Services', 9187), (u'contact', 9146), (u'best', 8984), (u'All', 8888), (u'clients', 8824), (u'over', 8803), (u'team', 8688), (u'solutions', 8664), (u'time', 8296), (u'needs', 8278), (u'design', 8270), (u'offer', 8267), (u'its', 8148), (u'information', 8130), (u'management', 8116), (u'which', 8053), (u'most', 8022), (u'home', 8020), (u'In', 8000), (u'was', 7942), (u'who', 7887), (u'based', 7837), (u'make', 7782), (u'customers', 7698), (u'products', 7669), (u'other', 7665), (u'been', 7555), (u'development', 7519), (u'what', 7502), (u'up', 7397), (u'support', 7165), (u'use', 7002), (u'companies', 6981), (u'than', 6922), (u'people', 6738), (u'well', 6655), (u'world', 6603), (u'get', 6557), (u'any', 6552), (u'professional', 6549), (u'need', 6531), (u'but', 6494)]
